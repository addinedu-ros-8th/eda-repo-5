# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd

seoul_regiest = pd.read_csv('')
seoul_regiest
# Out:
#      region_id pet_type_id      date result_id
# 0          도봉구      한국 고양이  20230330    종료(입양)
# 1          은평구      한국 고양이  20230330    종료(반환)
# 2          강서구         믹스견  20230330    종료(입양)
# 3          강서구         말티즈  20230330    종료(입양)
# 4          종로구         믹스묘  20230330    종료(입양)
# ...        ...         ...       ...       ...
# 4678       양천구      한국 고양이  20230531   종료(자연사)
# 4679      동대문구         믹스견  20230531    종료(입양)
# 4680       종로구      한국 고양이  20230531   종료(자연사)
# 4681       종로구         믹스견  20230531    종료(반환)
# 4682       관악구       포메라니안  20230531    종료(반환)
#
# [4683 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

result_counts = seoul_regiest['result_id'].value_counts()

# 파이 차트 생성
plt.figure(figsize=(12, 12))
plt.pie(result_counts, labels=result_counts.index, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.title('유기종류별 비중')
plt.show()

# %%
import matplotlib.pyplot as plt

# result_id별 데이터 개수 계산
result_counts = seoul_regiest['result_id'].value_counts()

# 파이 차트 생성
plt.figure(figsize=(12, 12))
plt.pie(
    result_counts, 
    labels=result_counts.index, 
    autopct='%1.1f%%', 
    startangle=90, 
    counterclock=False, 
    textprops={'fontsize': 14},  # 글자 크기 조정
    labeldistance=1.1  # 레이블 위치 조정
)
plt.title('유기종류별 비중', fontsize=18)  # 제목 폰트 크기 조정
plt.show()

# %%
import matplotlib.pyplot as plt

# result_id별 데이터 개수 계산
result_counts = seoul_regiest['result_id'].value_counts()

# 파이 차트 생성
plt.figure(figsize=(12, 12))
plt.pie(
    result_counts, 
    labels=None,  # 레이블 제거
    autopct='%1.1f%%',  # 비율을 내부에 표시
    startangle=90, 
    counterclock=False, 
    textprops={'fontsize': 14}  # 내부 텍스트 폰트 크기 조정
)
plt.title('유기종류별 비중', fontsize=18)  # 제목 폰트 크기 조정
plt.legend(result_counts.index, loc="best", fontsize=12)  # 범례 추가
plt.show()

# %%
# Filter out rows where result_id is "종료(반환)"
acture_abandent = seoul_regiest[seoul_regiest['result_id'] != "종료(반환)"]
# Out:
#   region_id pet_type_id      date result_id
# 0       도봉구      한국 고양이  20230330    종료(입양)
# 2       강서구         믹스견  20230330    종료(입양)
# 3       강서구         말티즈  20230330    종료(입양)
# 4       종로구         믹스묘  20230330    종료(입양)
# 6      영등포구         믹스견  20230329    종료(기증)

# %%
acture_abandent['result_id'].unique()
# Out:
# array(['종료(입양)', '종료(기증)', '종료(자연사)', '종료(방사)', '종료(안락사)', '보호중'],
#       dtype=object)

# %%
len(acture_abandent['result_id'].unique())
# Out:
# 6

# %%
acture_abandent = acture_abandent[acture_abandent['result_id'] != "보호중"]

# %%
acture_abandent['result_id'].unique()
# Out:
# array(['종료(입양)', '종료(기증)', '종료(자연사)', '종료(방사)', '종료(안락사)'], dtype=object)

# %%
len(acture_abandent['result_id'].unique())
# Out:
# 5

# %%
acture_abandent
# Out:
#      region_id pet_type_id      date result_id
# 0          도봉구      한국 고양이  20230330    종료(입양)
# 2          강서구         믹스견  20230330    종료(입양)
# 3          강서구         말티즈  20230330    종료(입양)
# 4          종로구         믹스묘  20230330    종료(입양)
# 6         영등포구         믹스견  20230329    종료(기증)
# ...        ...         ...       ...       ...
# 4676       양천구      한국 고양이  20230531    종료(입양)
# 4677       양천구      한국 고양이  20230531   종료(자연사)
# 4678       양천구      한국 고양이  20230531   종료(자연사)
# 4679      동대문구         믹스견  20230531    종료(입양)
# 4680       종로구      한국 고양이  20230531   종료(자연사)
#
# [3451 rows x 4 columns]

# %%
##실제 유기 되었다고 생각되는 데이터

acture_abandent.to_csv('')

# %%
acture_abandent
# Out:
#      region_id pet_type_id      date result_id
# 0          도봉구      한국 고양이  20230330    종료(입양)
# 2          강서구         믹스견  20230330    종료(입양)
# 3          강서구         말티즈  20230330    종료(입양)
# 4          종로구         믹스묘  20230330    종료(입양)
# 6         영등포구         믹스견  20230329    종료(기증)
# ...        ...         ...       ...       ...
# 4676       양천구      한국 고양이  20230531    종료(입양)
# 4677       양천구      한국 고양이  20230531   종료(자연사)
# 4678       양천구      한국 고양이  20230531   종료(자연사)
# 4679      동대문구         믹스견  20230531    종료(입양)
# 4680       종로구      한국 고양이  20230531   종료(자연사)
#
# [3451 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each pet_type_id and sort them in descending order
pet_type_counts = acture_abandent['pet_type_id'].value_counts()

# Plot the data
plt.figure(figsize=(10, 6))
pet_type_counts.sort_values(ascending=False).plot(kind='bar')
plt.title('상위 20개 유기품종', fontsize=14)
plt.xlabel('품종별', fontsize=12)
plt.ylabel('마릿수', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Select the top 20 pet types by count
top_20_pet_types = pet_type_counts.head(20)

# Plot the data for the top 20 pet types
plt.figure(figsize=(10, 6))
top_20_pet_types.sort_values(ascending=False).plot(kind='bar')
plt.title('상위 20개 유기품종', fontsize=14)
plt.xlabel('품종별', fontsize=12)
plt.ylabel('마릿수', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Remove whitespace in the 'pet_type_id' column and filter for '한국 고양이'
acture_abandent['pet_type_id'] = acture_abandent['pet_type_id'].str.strip()
korean_cats_data = acture_abandent[acture_abandent['pet_type_id'] == '한국 고양이']

# Count occurrences by 'region_id'
region_counts = korean_cats_data['region_id'].value_counts().sort_values(ascending=False)

# Plot the data
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
region_counts.plot(kind='bar')
plt.title("지역별 유기되는 고양이 숫자", fontsize=16)
plt.xlabel("지역", fontsize=14)
plt.ylabel("마릿수", fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
region_counts.plot(kind='bar', color=plt.cm.tab20.colors)
plt.title("지역별 유기되는 품종이 한국고양이인 숫자", fontsize=16)
plt.xlabel("지역", fontsize=14)
plt.ylabel("마릿수", fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Clean the 'pet_type_id' column to remove whitespace
acture_abandent['pet_type_id'] = acture_abandent['pet_type_id'].str.strip()

# Filter the data for pet_type_id == '믹스견'
mix_dog_data = acture_abandent[acture_abandent['pet_type_id'] == '믹스견']

# Count the occurrences of each region_id
region_counts = mix_dog_data['region_id'].value_counts().sort_values(ascending=False)

# Plot the data
plt.figure(figsize=(12, 8))
region_counts.plot(kind='bar', color=plt.cm.tab20.colors)
plt.title("지역별 유기되는 품종이 믹스견인 숫자", fontsize=16)
plt.xlabel("지역", fontsize=14)
plt.ylabel("마릿수", fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Renaming columns for easier processing


acture_abandent.columns = ['region_id', 'pet_type_id', 'date', 'result_id']

# Creating a pivot table for heatmap visualization
heatmap_data = acture_abandent.pivot_table(index='region_id', columns='pet_type_id', aggfunc='size', fill_value=0)

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title('Heatmap of Region vs Pet Type by Total Count')
plt.xlabel('Pet Type ID')
plt.ylabel('Region ID')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Limiting the heatmap data to the first 20 pet_type_id categories
heatmap_data_limited = heatmap_data.iloc[:, :20]

# Plotting the heatmap without annotations
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data_limited, annot=False, cmap="YlGnBu", cbar=True)
plt.title('Heatmap of Region vs Pet Type (First 20 Categories)')
plt.xlabel('Pet Type ID')
plt.ylabel('Region ID')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
registered_pets = pd.read_csv('/home/ted/dev_ws/EDA/eda-repo-5/0102/list/b_regiest_total.csv')
abandoned_pet_data = pd.read_csv('/home/ted/dev_ws/EDA/eda-repo-5/0102/list/f_seoul_ugi_2023.csv')

# %%
# Step 1: Prepare the registered pet data by grouping and aggregating
registered_pets = registered_pets.groupby(['region_id', 'pet_type_id'])['count'].sum().reset_index()
registered_pets.rename(columns={'count': 'registered_count'}, inplace=True)

# Step 2: Prepare the abandoned pet data by grouping and counting
abandoned_pets = abandoned_pet_data.groupby(['region_id', 'pet_type_id']).size().reset_index(name='abandoned_count')

# Step 3: Merge the datasets on region_id and pet_type_id
merged_data = pd.merge(registered_pets, abandoned_pets, on=['region_id', 'pet_type_id'], how='outer').fillna(0)

# Step 4: Add a column to calculate the abandonment rate
merged_data['abandonment_rate'] = (merged_data['abandoned_count'] / merged_data['registered_count']) * 100

# %%
abandoned_pet_data = pd.read_csv('/home/ted/dev_ws/EDA/eda-repo-5/0102/list/f_seoul_ugi_2023.csv')
abandoned_pet_data
# Out:
#       Unnamed: 0 region_id pet_type_id      date result_id
# 0              0       도봉구      한국 고양이  20230330    종료(입양)
# 1              2       강서구         믹스견  20230330    종료(입양)
# 2              3       강서구         말티즈  20230330    종료(입양)
# 3              4       종로구         믹스묘  20230330    종료(입양)
# 4              6      영등포구         믹스견  20230329    종료(기증)
# ...          ...       ...         ...       ...       ...
# 3446        4676       양천구      한국 고양이  20230531    종료(입양)
# 3447        4677       양천구      한국 고양이  20230531   종료(자연사)
# 3448        4678       양천구      한국 고양이  20230531   종료(자연사)
# 3449        4679      동대문구         믹스견  20230531    종료(입양)
# 3450        4680       종로구      한국 고양이  20230531   종료(자연사)
#
# [3451 rows x 5 columns]

# %%
abandoned_pet_data = abandoned_pet_data.drop(columns=['date', 'Unnamed: 0','result_id'])
abandoned_pet_data
# Out:
#      region_id pet_type_id
# 0          도봉구      한국 고양이
# 1          강서구         믹스견
# 2          강서구         말티즈
# 3          종로구         믹스묘
# 4         영등포구         믹스견
# ...        ...         ...
# 3446       양천구      한국 고양이
# 3447       양천구      한국 고양이
# 3448       양천구      한국 고양이
# 3449      동대문구         믹스견
# 3450       종로구      한국 고양이
#
# [3451 rows x 2 columns]

# %%
# Strip any leading or trailing whitespace from the columns used for merging
data['region_id'] = data['region_id'].str.strip()
data['pet_type_id'] = data['pet_type_id'].str.strip()
registration_data['region_id'] = registration_data['region_id'].str.strip()
registration_data['pet_type_id'] = registration_data['pet_type_id'].str.strip()

# Retry merging the datasets
merged_data = pd.merge(data, registration_data, on=["region_id", "pet_type_id"], how="inner", suffixes=('_abandoned', '_registered'))

# Recalculate the abandonment rate
merged_data['abandonment_rate'] = (merged_data['count_abandoned'] / merged_data['count_registered']) * 100

# Sort by abandonment rate in descending order
top_abandonment_rates = merged_data.sort_values(by="abandonment_rate", ascending=False)

# Select the top pet types with the highest abandonment rates
top_abandonment_rates_top10 = top_abandonment_rates.head(10)

# Plotting the corrected results
plt.figure(figsize=(10, 6))
plt.barh(top_abandonment_rates_top10['pet_type_id'], top_abandonment_rates_top10['abandonment_rate'])
plt.xlabel('Abandonment Rate (%)')
plt.ylabel('Pet Type')
plt.title('Top 10 Pet Types with Highest Abandonment Rates')
plt.gca().invert_yaxis()
plt.show()

# %%
# Strip any leading or trailing whitespace from the columns used for merging
data['region_id'] = data['region_id'].str.strip()
data['pet_type_id'] = data['pet_type_id'].str.strip()
registration_data['region_id'] = registration_data['region_id'].str.strip()
registration_data['pet_type_id'] = registration_data['pet_type_id'].str.strip()

# Retry merging the datasets
merged_data = pd.merge(data, registration_data, on=["region_id", "pet_type_id"], how="inner", suffixes=('_abandoned', '_registered'))

# Recalculate the abandonment rate
merged_data['abandonment_rate'] = (merged_data['count_registered'] / merged_data['count_abandoned'] ) * 100

# Sort by abandonment rate in descending order
top_abandonment_rates = merged_data.sort_values(by="abandonment_rate", ascending=False)

# Select the top pet types with the highest abandonment rates
top_abandonment_rates_top10 = top_abandonment_rates.head(10)

# Plotting the corrected results
plt.figure(figsize=(10, 6))
plt.barh(top_abandonment_rates_top10['pet_type_id'], top_abandonment_rates_top10['abandonment_rate'])
plt.xlabel('Abandonment Rate (%)')
plt.ylabel('Pet Type')
plt.title('Top 10 Pet Types with Highest Abandonment Rates')
plt.gca().invert_yaxis()
plt.show()

# %%
# Merge the datasets on region_id and pet_type_id
merged_data = pd.merge(
    registration_data,
    discarded_animal_data,
    on=["region_id", "pet_type_id"],
    how="outer"
).fillna(0)

# Ensure counts are integers
merged_data["count"] = merged_data["count"].astype(int)
merged_data["a_count"] = merged_data["a_count"].astype(int)

# Calculate discard-to-registration ratio
merged_data["discard_ratio"] = merged_data["a_count"] / (merged_data["count"] + 1e-6)  # Avoid division by zero

# %%
import matplotlib.pyplot as plt

# Aggregate data for visualizations
regional_data = merged_data.groupby("region_id")[["count", "a_count"]].sum()
regional_data["discard_ratio"] = regional_data["a_count"] / (regional_data["count"] + 1e-6)

# Top 10 regions with the highest discard-to-registration ratio
top_regions = regional_data.sort_values("discard_ratio", ascending=False).head(10)

# Plot 1: Registration and Discard Counts by Region (Top 10)
plt.figure(figsize=(12, 6))
top_regions[["count", "a_count"]].plot(kind="bar", stacked=True, alpha=0.75, figsize=(12, 6))
plt.title("유기수가 가장많은 지역 top10")
plt.ylabel("마릿수")
plt.xlabel("지역")
plt.xticks(rotation=45)
plt.legend(["Registered Pets", "Discarded Pets"])
plt.tight_layout()
plt.show()

# Plot 2: Discard Ratio by Region (Top 10)
plt.figure(figsize=(10, 5))
top_regions["discard_ratio"].plot(kind="bar", color='orange')
plt.title("지역별 비율 top10")
plt.ylabel("유기비율")
plt.xlabel("지역")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Aggregate data by pet type
pet_type_data = merged_data.groupby("pet_type_id")[["count", "a_count"]].sum()
pet_type_data["discard_ratio"] = pet_type_data["a_count"] / (pet_type_data["count"] + 1e-6)

# Top 10 pet types with the highest discard-to-registration ratio
top_pet_types = pet_type_data.sort_values("discard_ratio", ascending=False).head(10)

# Plot 3: Registration and Discard Counts by Pet Type (Top 10)
plt.figure(figsize=(12, 6))
top_pet_types[["count", "a_count"]].plot(kind="bar", stacked=True, alpha=0.75, figsize=(12, 6))
plt.title("Top 10 Pet Types: Registration vs. Discard Counts")
plt.ylabel("Count")
plt.xlabel("Pet Type")
plt.xticks(rotation=45)
plt.legend(["Registered Pets", "Discarded Pets"])
plt.tight_layout()
plt.show()

# Plot 4: Discard Ratio by Pet Type (Top 10)
plt.figure(figsize=(10, 5))
top_pet_types["discard_ratio"].plot(kind="bar", color='green')
plt.title("품종별 유기비율 top10")
plt.ylabel("유기비율")
plt.xlabel("품종")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Filter for regions with high discard-to-registration ratios
high_ratio_regions = merged_data[merged_data["discard_ratio"] > 0.5]  # Example threshold: >50% discard ratio

# Aggregate the filtered data by region
filtered_regional_data = high_ratio_regions.groupby("region_id")[["count", "a_count"]].sum()
filtered_regional_data["discard_ratio"] = filtered_regional_data["a_count"] / (filtered_regional_data["count"] + 1e-6)

# Sort by discard ratio
filtered_regional_data = filtered_regional_data.sort_values("discard_ratio", ascending=False)

# Plot: Registration and Discard Counts for High-Ratio Regions
plt.figure(figsize=(12, 6))
filtered_regional_data[["count", "a_count"]].plot(kind="bar", stacked=True, alpha=0.75)
plt.title("Regions with High Discard-to-Registration Ratios")
plt.ylabel("Count")
plt.xlabel("Region")
plt.xticks(rotation=45)
plt.legend(["Registered Pets", "Discarded Pets"])
plt.tight_layout()
plt.show()

# Plot: Discard Ratio for High-Ratio Regions
plt.figure(figsize=(10, 5))
filtered_regional_data["discard_ratio"].plot(kind="bar", color="red")
plt.title("Discard-to-Registration Ratio for High-Ratio Regions")
plt.ylabel("Discard Ratio")
plt.xlabel("Region")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
